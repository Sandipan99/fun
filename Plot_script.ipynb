# %%
from matplotlib.ticker import MultipleLocator, FormatStrFormatter,  AutoMinorLocator
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
import matplotlib as mpl
import numpy as np

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
#mpl.style.use('classic')
mpl.rcParams['xtick.labelsize'] = 35
mpl.rcParams['ytick.labelsize'] = 35
mpl.rcParams['font.size'] = 30
mpl.rcParams['figure.figsize'] =  10,8
mpl.rcParams['axes.labelsize'] = 35
mpl.rcParams['mathtext.fontset'] = 'stix'
mpl.rcParams['font.family'] = 'STIXGeneral'
mpl.rcParams['axes.linewidth'] = 4

# %%
Y = [0.842, 0.798, 0.744, 0.697, 0.672, 0.604, 0.560]
X = [0.14, 0.08, 0.05, 0.04, 0.03, 0.02, 0.01]

# %%
fig, ax = plt.subplots()
y_pos = np.arange(0.5,1.1,step=0.1)
ax.set_yticks(y_pos)
plt.ylim(0.5,0.9)
plt.xlim(0,0.2)
x_pos = np.arange(0,0.25,step=0.05)
ax.set_xticks(x_pos)

ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.xaxis.set_minor_locator(AutoMinorLocator())

ax.tick_params(which='both', width=2, direction='in')
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=6)

#ax.xaxis.set_minor_locator(AutoMinorLocator())


ax.tick_params(which='both', width=2, direction='in')
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=6)

ax.spines['top'].set_visible(False)  #Comment these out if you dont want to remove the borders
ax.spines['right'].set_visible(False)

plt.ylabel('Y-axis label')
plt.xlabel('X-axis label')
plt.grid(linestyle='--')

plt.plot(X, Y, 'v', linestyle='dashed', ms=13, label='Sample plot')
plt.legend(fontsize=22, loc=3)
plt.tight_layout()
#plt.savefig('fig.jpg', dpi=200)
plt.show()
